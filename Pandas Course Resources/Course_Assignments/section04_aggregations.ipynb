# %% [markdown]
# # Assignment 1: Groupby
#
# Can you return a table containing the top 10 stores by total transactions in the data?
#
# Make sure they’re sorted from highest to lowest.
#
# Thanks!

# %%
import pandas as pd
import numpy as np

# %%
# Read in transactions data -- parse dates specified here for help with later problem

transactions = pd.read_csv("../retail/transactions.csv", parse_dates=["date"])

transactions.head()
# Out:
#         date  store_nbr  transactions
# 0 2013-01-01         25           770
# 1 2013-01-02          1          2111
# 2 2013-01-02          2          2358
# 3 2013-01-02          3          3487
# 4 2013-01-02          4          1922

# %%
# sum transactions for each store, display 10 highest
transactions.groupby('store_nbr')[['transactions']].sum().sort_values('transactions', ascending=False).head(10)
# Out:
#            transactions
# store_nbr
# 44              7273093
# 47              6535810
# 45              6201115
# 46              5990113
# 3               5366350
# 48              5107785
# 8               4637971
# 49              4574103
# 50              4384444
# 11              3972488

# %% [markdown]
# # Assignment 2: Groupby Multiple Columns
#
# Can you get me the total transactions by store and month?
#
# Sort the table from first month to last, then by highest transactions to lowest within each month.

# %%
# helper code to extract month date part from date column

transactions["month"] = transactions["date"].dt.month

transactions.head()
# Out:
#         date  store_nbr  transactions  month
# 0 2013-01-01         25           770      1
# 1 2013-01-02          1          2111      1
# 2 2013-01-02          2          2358      1
# 3 2013-01-02          3          3487      1
# 4 2013-01-02          4          1922      1

# %%
# sum transactions for each store, each month. display highest monthly transactions to lowest monthly transactions
transactions.groupby(['store_nbr','month'])[['transactions']].sum().sort_values(by=['month', 'transactions'], ascending=[True,False])
# Out:
#                  transactions
# store_nbr month
# 44        1            628438
# 47        1            568824
# 45        1            538370
# 46        1            522763
# 3         1            463260
# ...                       ...
# 32        12            86167
# 21        12            84128
# 42        12            76741
# 29        12            76627
# 22        12            50650
#
# [641 rows x 1 columns]

# %% [markdown]
# # Assignment 3: Multi-Index DataFrames
#
#
# Can you help me access rows and columns with multiple indices? I’ve been struggling with multi-index DataFrames.
#
# Access:
# * Grab Store 3, Month 1
# * Then, select the column storing the mean of transactions
#
# Fix:
# * Drop the outer layer of the column Index
# * Reset the row index so it is the default integer index

# %%
# Ross' grouped DataFrame code, run this first

grouped = (
    transactions.groupby(["store_nbr", "month"])
    .agg({"transactions": ["sum", "mean"]})
    .sort_values(by=["month", ("transactions", "sum")], ascending=[True, False])
)

# %%
# df grouped by store and month with two aggregation columns
grouped.head()
# Out:
#                 transactions
#                          sum         mean
# store_nbr month
# 44        1           628438  4246.202703
# 47        1           568824  3843.405405
# 45        1           538370  3637.635135
# 46        1           522763  3532.182432
# 3         1           463260  3151.428571

# %%
# grab store 3, month 1
grouped.loc[[(3,1)]]
# Out:
#                 transactions
#                          sum         mean
# store_nbr month
# 3         1           463260  3151.428571

# %%
# grab store 3, month 1 and mean --> Wrap both tuples like this [[()],[()]] to have result as DataFrame
grouped.loc[[(3,1)],[('transactions','mean')]]
# Out:
#                 transactions
#                         mean
# store_nbr month
# 3         1      3151.428571

# %%
# or just grab the mean column for all rows
grouped.loc[:,[('transactions','mean')]]
# Out:
#                 transactions
#                         mean
# store_nbr month
# 44        1      4246.202703
# 47        1      3843.405405
# 45        1      3637.635135
# 46        1      3532.182432
# 3         1      3151.428571
# ...                      ...
# 32        12      718.058333
# 21        12     1402.133333
# 42        12     1279.016667
# 29        12     1277.116667
# 22        12      844.166667
#
# [641 rows x 1 columns]

# %%
grouped.head()
# Out:
#                 transactions
#                          sum         mean
# store_nbr month
# 44        1           628438  4246.202703
# 47        1           568824  3843.405405
# 45        1           538370  3637.635135
# 46        1           522763  3532.182432
# 3         1           463260  3151.428571

# %%
# drop the outer layer of the column index (remove 'transaction' label)
# then reset_index() row index to be integer
grouped.droplevel(0, axis = 1).reset_index()
# Out:
#      store_nbr  month     sum         mean
# 0           44      1  628438  4246.202703
# 1           47      1  568824  3843.405405
# 2           45      1  538370  3637.635135
# 3           46      1  522763  3532.182432
# 4            3      1  463260  3151.428571
# ..         ...    ...     ...          ...
# 636         32     12   86167   718.058333
# 637         21     12   84128  1402.133333
# 638         42     12   76741  1279.016667
# 639         29     12   76627  1277.116667
# 640         22     12   50650   844.166667
#
# [641 rows x 4 columns]

# %% [markdown]
# # Assignment 4: The Agg Method
#
# Calculate the mean of target met by store, and the sum of bonuses to be paid to each store.
#
# Sort them by highest to lowest bonus payout.
#
# Then, do the same for day of week and month.

# %%
# Recreate table from section 3

transactions = transactions.assign(
    target_pct=transactions["transactions"] / 2500,
    met_target=(transactions["transactions"] / 2500) >= 1,
    bonus_payable=((transactions["transactions"] / 2500) >= 1) * 100,
    month=transactions.date.dt.month,
    day_of_week=transactions.date.dt.dayofweek,
)

transactions.head()
# Out:
#         date  store_nbr  transactions  month  target_pct  met_target  \
# 0 2013-01-01         25           770      1      0.3080       False
# 1 2013-01-02          1          2111      1      0.8444       False
# 2 2013-01-02          2          2358      1      0.9432       False
# 3 2013-01-02          3          3487      1      1.3948        True
# 4 2013-01-02          4          1922      1      0.7688       False
#
#    bonus_payable  day_of_week
# 0              0            1
# 1              0            2
# 2              0            2
# 3            100            2
# 4              0            2

# %%
# calculate mean of target met by store and sum bonuses paid to each store
transactions.groupby('store_nbr').agg(
    # average of the True values by day (True = 1)
    met_target=('met_target', 'mean'),
    # sum the bonus_payable 
    bonus_payable = ('bonus_payable', 'sum')
    # sort DataFrame descending for Bonus amount
    ).sort_values(by='bonus_payable', ascending=False).head()
# Out:
#            met_target  bonus_payable
# store_nbr
# 47           0.999404         167600
# 44           0.998807         167500
# 45           0.997615         167300
# 3            0.998210         167300
# 46           0.989267         165900

# %%
# could be done without named columns using dictionary
transactions.groupby(['store_nbr']).agg(
    {'met_target':'mean','bonus_payable':'sum'}
    ).sort_values(by='bonus_payable', ascending=False).head()
# Out:
#            met_target  bonus_payable
# store_nbr
# 47           0.999404         167600
# 44           0.998807         167500
# 45           0.997615         167300
# 3            0.998210         167300
# 46           0.989267         165900

# %%
# calculate mean of target met by month and sum bonuses paid by month
transactions.groupby('month').agg(
    # average of the True values by day (True = 1)
    met_target=('met_target', 'mean'),
    # sum the bonus_payable 
    bonus_payable = ('bonus_payable', 'sum')
    # sort DataFrame descending for Bonus amount
    ).sort_values(by='bonus_payable', ascending=False).head()
# Out:
#        met_target  bonus_payable
# month
# 12       0.255640         154100
# 5        0.170792         131800
# 3        0.169461         130400
# 4        0.174469         129700
# 7        0.162486         126300

# %%
# could be done without named columns using dictionary
transactions.groupby(['month']).agg(
    {'met_target':'mean','bonus_payable':'sum'}
    ).sort_values(by='bonus_payable', ascending=False).head()
# Out:
#        met_target  bonus_payable
# month
# 12       0.255640         154100
# 5        0.170792         131800
# 3        0.169461         130400
# 4        0.174469         129700
# 7        0.162486         126300

# %%
# calculate mean of target met by day and sum bonuses paid by day
transactions.groupby('day_of_week').agg(
    # average of the True values by day (True = 1)
    met_target=('met_target', 'mean'),
    # sum the bonus_payable 
    bonus_payable = ('bonus_payable', 'sum')
    # sort DataFrame descending for Bonus amount
    ).sort_values(by='bonus_payable', ascending=False).head()
# Out:
#              met_target  bonus_payable
# day_of_week
# 5              0.222204         266400
# 6              0.204001         241700
# 4              0.179007         213000
# 0              0.160214         191600
# 2              0.160572         191000

# %%
# could be done without named columns using dictionary
transactions.groupby(['day_of_week']).agg(
    {'met_target':'mean','bonus_payable':'sum'}
    ).sort_values(by='bonus_payable', ascending=False).head()
# Out:
#              met_target  bonus_payable
# day_of_week
# 5              0.222204         266400
# 6              0.204001         241700
# 4              0.179007         213000
# 0              0.160214         191600
# 2              0.160572         191000

# %% [markdown]
# # Assignment 4: Transform
#
# Calculate the mean of transactions by store number and day of week while keeping row numbers.
#
# Then compare the performance of each row to its day of week average. (difference between transactions and daily avg)

# %%
# calc avg transactions by store_nbr and day_of_week using .transform() to keep row numbers with .assign() to create column
transactions.assign(
    avg_store_trans = transactions.groupby(['store_nbr','day_of_week'])['transactions'].transform('mean')
    ).head()
# Out:
#         date  store_nbr  transactions  month  target_pct  met_target  \
# 0 2013-01-01         25           770      1      0.3080       False
# 1 2013-01-02          1          2111      1      0.8444       False
# 2 2013-01-02          2          2358      1      0.9432       False
# 3 2013-01-02          3          3487      1      1.3948        True
# 4 2013-01-02          4          1922      1      0.7688       False
#
#    bonus_payable  day_of_week  avg_store_trans
# 0              0            1       740.245690
# 1              0            2      1870.782427
# 2              0            2      1952.652720
# 3            100            2      3142.682008
# 4              0            2      1499.569038

# %%
#  create additional column for differnce between transactions and (calc avg transactions by store_nbr and day_of_week using .transform() to keep row numbers with .assign() to create column) at row level
transactions.assign(
    avg_store_trans = transactions.groupby(['store_nbr','day_of_week'])['transactions'].transform('mean'),
    trans_difference = lambda x: x['transactions'] - x['avg_store_trans']
    ).head()
# Out:
#         date  store_nbr  transactions  month  target_pct  met_target  \
# 0 2013-01-01         25           770      1      0.3080       False
# 1 2013-01-02          1          2111      1      0.8444       False
# 2 2013-01-02          2          2358      1      0.9432       False
# 3 2013-01-02          3          3487      1      1.3948        True
# 4 2013-01-02          4          1922      1      0.7688       False
#
#    bonus_payable  day_of_week  avg_store_trans  trans_difference
# 0              0            1       740.245690         29.754310
# 1              0            2      1870.782427        240.217573
# 2              0            2      1952.652720        405.347280
# 3            100            2      3142.682008        344.317992
# 4              0            2      1499.569038        422.430962

# %% [markdown]
# # Assignment 5: Pivot
#
# Pivot transactions with store number as index, columns day of week, with the sum of bonus payable as cells.
#
# Filter to stores that had a non-zero bonus payable and create a heatmap.
#
# Then unpivot (melt) the table so we have one row for each store and day of the week with the corresponding total owed.

# %%
# Use transactions table (ok if includes columns from assignment 4 or not)

transactions.head()
# Out:
#         date  store_nbr  transactions  month  target_pct  met_target  \
# 0 2013-01-01         25           770      1      0.3080       False
# 1 2013-01-02          1          2111      1      0.8444       False
# 2 2013-01-02          2          2358      1      0.9432       False
# 3 2013-01-02          3          3487      1      1.3948        True
# 4 2013-01-02          4          1922      1      0.7688       False
#
#    bonus_payable  day_of_week
# 0              0            1
# 1              0            2
# 2              0            2
# 3            100            2
# 4              0            2

# %%
# create pivot_table that has store_nbr as index, day_of_week as columns, and values of the bonus is summed in the columns
day_bonus = transactions.pivot_table(
    index='store_nbr',
    columns='day_of_week',
    values='bonus_payable',
    aggfunc='sum'
    ).head(11)
day_bonus
# Out:
# day_of_week      0      1      2      3      4      5      6
# store_nbr
# 1              200    300    300    200    100      0      0
# 2              300    600    500    400    400    500    200
# 3            24000  23900  23900  23900  23900  24000  23700
# 4              200    300    300    200    100    200      0
# 5              200    300    300    100    100    100      0
# 6              400    500    500    300    200    900    300
# 7              200    300    300    200    100    100      0
# 8            22000  18800  23800  18000  22900  23400  20000
# 9             1200    800    800    700    400   7900   5100
# 10               0      0      0      0      0      0      0
# 11            3500   4800   3200   3000   2000  15600  17600

# %%
# create heatmap for pivot_table that has store_nbr as index, day_of_week as columns, and values of the bonus is summed in the columns
heatmap = transactions.pivot_table(
    index='store_nbr',
    columns='day_of_week',
    values='bonus_payable',
    aggfunc='sum'
    ).head(11).style.background_gradient(cmap='RdYlGn', axis = 1)
heatmap
# Out:
# <style type="text/css">
# #T_8ab32_row0_col0, #T_8ab32_row0_col3, #T_8ab32_row2_col1, #T_8ab32_row2_col2, #T_8ab32_row2_col3, #T_8ab32_row2_col4, #T_8ab32_row3_col0, #T_8ab32_row3_col3, #T_8ab32_row3_col5, #T_8ab32_row4_col0, #T_8ab32_row6_col0, #T_8ab32_row6_col3 {
#   background-color: #b7e075;
#   color: #000000;
# }
# #T_8ab32_row0_col1, #T_8ab32_row0_col2, #T_8ab32_row1_col1, #T_8ab32_row2_col0, #T_8ab32_row2_col5, #T_8ab32_row3_col1, #T_8ab32_row3_col2, #T_8ab32_row4_col1, #T_8ab32_row4_col2, #T_8ab32_row5_col5, #T_8ab32_row6_col1, #T_8ab32_row6_col2, #T_8ab32_row7_col2, #T_8ab32_row8_col5, #T_8ab32_row10_col6 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_8ab32_row0_col4, #T_8ab32_row3_col4, #T_8ab32_row4_col3, #T_8ab32_row4_col4, #T_8ab32_row4_col5, #T_8ab32_row6_col4, #T_8ab32_row6_col5 {
#   background-color: #fdbf6f;
#   color: #000000;
# }
# #T_8ab32_row0_col5, #T_8ab32_row0_col6, #T_8ab32_row1_col6, #T_8ab32_row2_col6, #T_8ab32_row3_col6, #T_8ab32_row4_col6, #T_8ab32_row5_col4, #T_8ab32_row6_col6, #T_8ab32_row7_col3, #T_8ab32_row8_col4, #T_8ab32_row9_col0, #T_8ab32_row9_col1, #T_8ab32_row9_col2, #T_8ab32_row9_col3, #T_8ab32_row9_col4, #T_8ab32_row9_col5, #T_8ab32_row9_col6, #T_8ab32_row10_col4 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_8ab32_row1_col0 {
#   background-color: #f98e52;
#   color: #f1f1f1;
# }
# #T_8ab32_row1_col2, #T_8ab32_row1_col5 {
#   background-color: #84ca66;
#   color: #000000;
# }
# #T_8ab32_row1_col3, #T_8ab32_row1_col4 {
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_8ab32_row5_col0 {
#   background-color: #fca55d;
#   color: #000000;
# }
# #T_8ab32_row5_col1, #T_8ab32_row5_col2 {
#   background-color: #fee999;
#   color: #000000;
# }
# #T_8ab32_row5_col3, #T_8ab32_row5_col6 {
#   background-color: #e34933;
#   color: #f1f1f1;
# }
# #T_8ab32_row7_col0 {
#   background-color: #abdb6d;
#   color: #000000;
# }
# #T_8ab32_row7_col1 {
#   background-color: #e24731;
#   color: #f1f1f1;
# }
# #T_8ab32_row7_col4 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
# }
# #T_8ab32_row7_col5 {
#   background-color: #118848;
#   color: #f1f1f1;
# }
# #T_8ab32_row7_col6 {
#   background-color: #fdc574;
#   color: #000000;
# }
# #T_8ab32_row8_col0 {
#   background-color: #d93429;
#   color: #f1f1f1;
# }
# #T_8ab32_row8_col1, #T_8ab32_row8_col2 {
#   background-color: #be1827;
#   color: #f1f1f1;
# }
# #T_8ab32_row8_col3 {
#   background-color: #b91326;
#   color: #f1f1f1;
# }
# #T_8ab32_row8_col6 {
#   background-color: #cbe982;
#   color: #000000;
# }
# #T_8ab32_row10_col0 {
#   background-color: #d42d27;
#   color: #f1f1f1;
# }
# #T_8ab32_row10_col1 {
#   background-color: #ed5f3c;
#   color: #f1f1f1;
# }
# #T_8ab32_row10_col2 {
#   background-color: #ca2427;
#   color: #f1f1f1;
# }
# #T_8ab32_row10_col3 {
#   background-color: #c41e27;
#   color: #f1f1f1;
# }
# #T_8ab32_row10_col5 {
#   background-color: #2da155;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8ab32">
#   <thead>
#     <tr>
#       <th class="index_name level0" >day_of_week</th>
#       <th id="T_8ab32_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_8ab32_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_8ab32_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_8ab32_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_8ab32_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_8ab32_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_8ab32_level0_col6" class="col_heading level0 col6" >6</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >store_nbr</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8ab32_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_8ab32_row0_col0" class="data row0 col0" >200</td>
#       <td id="T_8ab32_row0_col1" class="data row0 col1" >300</td>
#       <td id="T_8ab32_row0_col2" class="data row0 col2" >300</td>
#       <td id="T_8ab32_row0_col3" class="data row0 col3" >200</td>
#       <td id="T_8ab32_row0_col4" class="data row0 col4" >100</td>
#       <td id="T_8ab32_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_8ab32_row0_col6" class="data row0 col6" >0</td>
#     </tr>
#     <tr>
#       <th id="T_8ab32_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_8ab32_row1_col0" class="data row1 col0" >300</td>
#       <td id="T_8ab32_row1_col1" class="data row1 col1" >600</td>
#       <td id="T_8ab32_row1_col2" class="data row1 col2" >500</td>
#       <td id="T_8ab32_row1_col3" class="data row1 col3" >400</td>
#       <td id="T_8ab32_row1_col4" class="data row1 col4" >400</td>
#       <td id="T_8ab32_row1_col5" class="data row1 col5" >500</td>
#       <td id="T_8ab32_row1_col6" class="data row1 col6" >200</td>
#     </tr>
#     <tr>
#       <th id="T_8ab32_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_8ab32_row2_col0" class="data row2 col0" >24000</td>
#       <td id="T_8ab32_row2_col1" class="data row2 col1" >23900</td>
#       <td id="T_8ab32_row2_col2" class="data row2 col2" >23900</td>
#       <td id="T_8ab32_row2_col3" class="data row2 col3" >23900</td>
#       <td id="T_8ab32_row2_col4" class="data row2 col4" >23900</td>
#       <td id="T_8ab32_row2_col5" class="data row2 col5" >24000</td>
#       <td id="T_8ab32_row2_col6" class="data row2 col6" >23700</td>
#     </tr>
#     <tr>
#       <th id="T_8ab32_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_8ab32_row3_col0" class="data row3 col0" >200</td>
#       <td id="T_8ab32_row3_col1" class="data row3 col1" >300</td>
#       <td id="T_8ab32_row3_col2" class="data row3 col2" >300</td>
#       <td id="T_8ab32_row3_col3" class="data row3 col3" >200</td>
#       <td id="T_8ab32_row3_col4" class="data row3 col4" >100</td>
#       <td id="T_8ab32_row3_col5" class="data row3 col5" >200</td>
#       <td id="T_8ab32_row3_col6" class="data row3 col6" >0</td>
#     </tr>
#     <tr>
#       <th id="T_8ab32_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_8ab32_row4_col0" class="data row4 col0" >200</td>
#       <td id="T_8ab32_row4_col1" class="data row4 col1" >300</td>
#       <td id="T_8ab32_row4_col2" class="data row4 col2" >300</td>
#       <td id="T_8ab32_row4_col3" class="data row4 col3" >100</td>
#       <td id="T_8ab32_row4_col4" class="data row4 col4" >100</td>
#       <td id="T_8ab32_row4_col5" class="data row4 col5" >100</td>
#       <td id="T_8ab32_row4_col6" class="data row4 col6" >0</td>
#     </tr>
#     <tr>
#       <th id="T_8ab32_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_8ab32_row5_col0" class="data row5 col0" >400</td>
#       <td id="T_8ab32_row5_col1" class="data row5 col1" >500</td>
#       <td id="T_8ab32_row5_col2" class="data row5 col2" >500</td>
#       <td id="T_8ab32_row5_col3" class="data row5 col3" >300</td>
#       <td id="T_8ab32_row5_col4" class="data row5 col4" >200</td>
#       <td id="T_8ab32_row5_col5" class="data row5 col5" >900</td>
#       <td id="T_8ab32_row5_col6" class="data row5 col6" >300</td>
#     </tr>
#     <tr>
#       <th id="T_8ab32_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_8ab32_row6_col0" class="data row6 col0" >200</td>
#       <td id="T_8ab32_row6_col1" class="data row6 col1" >300</td>
#       <td id="T_8ab32_row6_col2" class="data row6 col2" >300</td>
#       <td id="T_8ab32_row6_col3" class="data row6 col3" >200</td>
#       <td id="T_8ab32_row6_col4" class="data row6 col4" >100</td>
#       <td id="T_8ab32_row6_col5" class="data row6 col5" >100</td>
#       <td id="T_8ab32_row6_col6" class="data row6 col6" >0</td>
#     </tr>
#     <tr>
#       <th id="T_8ab32_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_8ab32_row7_col0" class="data row7 col0" >22000</td>
#       <td id="T_8ab32_row7_col1" class="data row7 col1" >18800</td>
#       <td id="T_8ab32_row7_col2" class="data row7 col2" >23800</td>
#       <td id="T_8ab32

# %%
# melt the DataFrame to have one row for each store and day of the week with total owed, column_index must be reset because of id_vars argument
day_bonus.reset_index().melt(
    id_vars='store_nbr',
    value_name='bonus_payable'
)
# Out:
#     store_nbr day_of_week  bonus_payable
# 0           1           0            200
# 1           2           0            300
# 2           3           0          24000
# 3           4           0            200
# 4           5           0            200
# ..        ...         ...            ...
# 72          7           6              0
# 73          8           6          20000
# 74          9           6           5100
# 75         10           6              0
# 76         11           6          17600
#
# [77 rows x 3 columns]
